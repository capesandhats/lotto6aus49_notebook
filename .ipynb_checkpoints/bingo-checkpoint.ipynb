# %%
import pandas as pd 
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt
from IPython.display import display
import os


plt.rcParams['figure.figsize'] = [40, 9]
plt.rcParams['figure.dpi']=1000

pd.options.display.max_colwidth =100
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# <a id='the_destination'></a>

# %%
INITIAL_COUNT = 57
COUNTERS_DF = pd.DataFrame()
FILTERED_DF = pd.DataFrame()
FREQUENCY_ORDER_OF_NUMBERS =""
DIR_NAME = os.getcwd()

# %% [markdown]
# ## ReadFiles

# %%
df2018=pd.read_csv(os.path.join(DIR_NAME, 'lottodata/2018.txt'))
df2017=pd.read_csv(os.path.join(DIR_NAME, 'lottodata/2017.txt'))
df2016=pd.read_csv(os.path.join(DIR_NAME, 'lottodata/2016.txt'))

#fromating data

dt2018 =df2018.rename(columns={'Date': 'date', 'number1' : 'n1', 'number2':'n2', 'number3':'n3', 'number4':'n4', 'number5':'n5',
       'number6':'n6', 'number7':'n7', 'jackpot clamied': 'jackpot'}, index ={})
dt2018.date= pd.to_datetime(dt2018.date)

dt2017 =df2017.rename(columns={'Date': 'date', 'number1' : 'n1', 'number2':'n2', 'number3':'n3', 'number4':'n4', 'number5':'n5',
       'number6':'n6', 'number7':'n7', 'jackpot clamied': 'jackpot'}, index ={})
dt2017.date= pd.to_datetime(dt2017.date)

dt2016 =df2016.rename(columns={'Date': 'date', 'number1' : 'n1', 'number2':'n2', 'number3':'n3', 'number4':'n4', 'number5':'n5',
       'number6':'n6', 'number7':'n7', 'jackpot clamied': 'jackpot'}, index ={})
dt2016.date= pd.to_datetime(dt2016.date)

frames = [dt2018,dt2017,dt2016]
dt = pd.concat(frames)
dt.reset_index(inplace=True, drop=True) 
print("Loaded data from :", dt.iloc[dt.date.size-1][0]," to :", dt.iloc[0][0])
dt
# Out:
# Loaded data from : 2016-01-02 00:00:00  to : 2018-08-01 00:00:00
#           date  n1  n2  n3  n4  n5  n6  n7     jackpot
# 0   2018-08-01   2  22  25  32  45  46   2   5000000 R
# 1   2018-07-28   7  11  31  34  35  36   1   4000000 R
# 2   2018-07-25   8   9  39  40  41  43   9   1000000 R
# 3   2018-07-21   1   6   7  20  29  49   5     6931435
# 4   2018-07-18   5  14  19  22  33  41   1   4000000 R
# 5   2018-07-14  30  40  41  47  48  49   0   2000000 R
# 6   2018-07-11   1   3  18  28  42  44   5     5322768
# 7   2018-07-07   2   5  13  18  25  36   2   4000000 R
# 8   2018-07-04   1   5  10  25  32  37   8   1000000 R
# 9   2018-06-30  16  24  37  38  40  42   9    10578110
# 10  2018-06-27  13  17  35  37  45  46   3   5000000 R
# 11  2018-06-23   6  17  25  29  48  49   1   4000000 R
# 12  2018-06-20   6  22  31  33  36  43   5   1000000 R
# 13  2018-06-16   4  19  31  33  40  46   2     8098317
# 14  2018-06-13   3   4   6  10  46  48   3   5000000 R
# 15  2018-06-09  13  16  34  35  39  42   9   4000000 R
# 16  2018-06-06   3   8  13  15  18  42   6   1000000 R
# 17  2018-06-02   1  10  19  24  30  31   7     3433497
# 18  2018-05-30  15  23  29  35  38  48   2   4000000 R
# 19  2018-05-26  10  16  24  27  47  48   6   3000000 R
# 20  2018-05-23   7  16  29  36  45  47   6    11352208
# 230 2016-05-11  10  19  20  31  39  41   5  30000000 R
# 231 2016-05-07  16  32  34  37  42  44   9  28000000 R
# 232 2016-05-04   2  11  14  35  39  49   5  24000000 R
# 233 2016-04-30  14  26  28  30  36  43   6  22000000 R
# 234 2016-04-27   1   6   9  21  26  37   6  18000000 R
# 235 2016-04-23   8  15  16  17  27  35   4  17000000 R
# 236 2016-04-20   1   5  11  13  20  49   8  13000000 R
# 237 2016-04-16   5  14  15  20  22  38   9  12000000 R
# 238 2016-04-13   2  13  17  35  36  49   7   9000000 R
# 239 2016-04-09   1   4  38  39  46  47   2   7000000 R
# 240 2016-04-06   6  19  25  30  33  42   4   4000000 R
# 241 2016-04-02   1  10  17  23  28  38   6   3000000 R
# 242 2016-03-30   1   5   9  13  26  41   1     5319644
# 243 2016-03-26   1   3  31  33  40  41   5   3000000 R
# 244 2016-03-23   9  10  16  22  31  44   0     9106378
# 245 2016-03-19   4  10  15  37  44  49   5   7000000 R
# 246 2016-03-16   9  11  26  29  35  46   6   4000000 R
# 247 2016-03-12  20  26  30  39  47  49   4   3000000 R
# 248 2016-03-09  10  13  32  37  46  48   7     6019797
# 249 2016-03-05   7  10  33  37  43  46   3   4000000 R
# 250 2016-03-02   1   8  10  16  17  40   9   1000000 R
# 251 2016-02-27   7  10  15  25  37  49   7     4466455
# 252 2016-02-24   5  13  23  31  47  48   5   1000000 R
# 253 2016-02-20   1  13  16  29  30  31   6     4529955
# 254 2016-02-17  24  26  32  35  38  39   3   1000000 R
# 255 2016-02-13  18  20  30  32  43  45   8     9649160
# 256 2016-02-10   2  17  19  32  34  38   4  15000000 R
# 257 2016-02-06  10  16  25  28  34  49   5  14000000 R
# 258 2016-02-03  10  18  19  31  33  47   8  10000000 R
# 259 2016-01-30  18  23  33  34  40  48   9   9000000 R
# 260 2016-01-27  12  14  16  19  29  47   3   5000000 R
# 261 2016-01-23   2  16  25  26  27  40   0   4000000 R
# 262 2016-01-20   7  12  14  15  19  46   3   1000000 R
# 263 2016-01-16   9  21  23  31  34  39   8     4502793
# 264 2016-01-13  14  18  19  25  35  46   0   1000000 R
# 265 2016-01-09  10  13  31  34  46  48   6     6850686
# 266 2016-01-06   3  12  27  36  42  45   0  10000000 R
# 267 2016-01-02   1  23  30  35  43  47   8   9000000 R

# %% [markdown]
# ## Define Functions

# %%
def do_calculate_frequency(filter_df):
    n1c=Counter(filter_df.n1)
    n2c=Counter(filter_df.n2)
    n3c=Counter(filter_df.n3)
    n4c=Counter(filter_df.n4)
    n5c=Counter(filter_df.n5)
    n6c=Counter(filter_df.n6)
    sum1 = n1c+n2c+n3c+n4c+n5c+n6c
    data = [sum1,n1c,n2c,n3c,n4c,n5c,n6c]
    index = ["sum","first", "second", "third", "forth", "fifth", "six"]
    temp =pd.DataFrame(data, index=index)
    temp=temp.replace(np.nan,0)
    temp=temp.astype('int')
    datacounter=temp.transpose()
    datacounter=datacounter.sort_values(by='sum', ascending=False)    
    return datacounter

def do_counter_barplot(datacounter):  
    
    #plt.figure(figsize=(40, 9), dpi= 1000, facecolor='w', edgecolor='k')
    #datacounter.plot.hist(alpha=1)
    plt.rcParams['figure.figsize'] = [9, 2.5]
    plt.rcParams['figure.dpi']=200
    plt.figure()
    datacounter.plot.bar()

def do_print_counter(datacounter):
    t = datacounter
    t['position'] = pd.Series(np.array(range(1,datacounter.index.size+1,1)), index=datacounter.index)
    global COUNTERS_DF 
    COUNTERS_DF = t
    #t = datacounter.transpose()    
    #t['index'] = pd.series(range(1,49,1))
    #t.style.set_include_index(True) 
    #display(t.style)    
    display(t.transpose().style)

# %% [markdown]
# ## Frequency of numbers

# %%
import ipywidgets as widgets
from ipywidgets import interact, HBox, Label

def view(y=INITIAL_COUNT):
    filter_df = dt.head(y)
    print("starting from date :", filter_df.iloc[filter_df.date.size-1][0] )
    print("number of draws :", y ,"from " , filter_df.iloc[0][0] )
    counters = do_calculate_frequency(filter_df=filter_df)
    do_counter_barplot(datacounter = counters)
    do_print_counter(datacounter = counters)
    
    global FILTERED_DF 
    FILTERED_DF = filter_df
    
    global COUNTERS_DF 
    COUNTERS_DF = counters
    
    #do_order_of_frequency(a)
    #print(counters.transpose())
    #return

style = {'description_width': 'initial'}
a_slider = widgets.BoundedIntText(min=0, max=dt.date.size, step=1, value=INITIAL_COUNT, description='number of entries: ', sytle=style)
widgets.interact(view,y=a_slider)
# Out:
# interactive(children=(BoundedIntText(value=57, description='number of entries: ', max=268), Output()), _dom_cl…
# <function __main__.view(y=57)>

# %% [markdown]
# ## Find the Position of the draw from  the counts

# %%
def do_order_of_frequency(a =[1,1,1,1,1,11]):
    i=0
    order = []
    return_string = "order of " + str(a) +": "
    
    while i < len(a) : 
        #return_string += str(a[i]) + " : " + str(COUNTERS_DF.iloc[COUNTERS_DF.index.get_loc(a[i])][7])+ " , " 
        #order[i] = COUNTERS_DF.iloc[COUNTERS_DF.index.get_loc(a[i])][7]
        try:
            order.append(COUNTERS_DF.iloc[COUNTERS_DF.index.get_loc(a[i])][7])
        except KeyError:
            order.append(-1)
        #return_string += str(COUNTERS_DF.iloc[COUNTERS_DF.index.get_loc(a[i])][7])+ " , " 
        i += 1
    #print(order)
    global FREQUENCY_ORDER_OF_NUMBERS
    FREQUENCY_ORDER_OF_NUMBERS = return_string + str(order) + " , [Max, Min]: [" + str(max(order)) + " , " +str(min(order)) +" , " + str(np.mean(order))+ "]"
    return FREQUENCY_ORDER_OF_NUMBERS        
a = [7,11,31,34,35,36]
do_order_of_frequency(a)    
print(do_order_of_frequency(a))
a = [8,9,39,40,41,43]    
print(do_order_of_frequency(a))
a = [1,6,7,20,29,49]    
print(do_order_of_frequency(a))
a = [5,14,19,22,33,41]    
print(do_order_of_frequency(a))
a = [30,40,41,47,48,49]    
print(do_order_of_frequency(a))
a = [1,3,18,28,42,44]    
print(do_order_of_frequency(a))
a = [2,5,13,18,25,36]    
print(do_order_of_frequency(a))
a = [1,5,10,25,32,37]    
print(do_order_of_frequency(a))

a_slider
#FREQUENCY_ORDER_OF_NUMBERS
# Out:
# order of [7, 11, 31, 34, 35, 36]: [40, 45, 11, 10, 18, 23] , [Max, Min]: [45 , 10 , 24.5]
# order of [8, 9, 39, 40, 41, 43]: [42, 36, 46, 29, 25, 27] , [Max, Min]: [46 , 25 , 34.166666666666664]
# order of [1, 6, 7, 20, 29, 49]: [20, 17, 40, 34, 9, 30] , [Max, Min]: [40 , 9 , 25.0]
# order of [5, 14, 19, 22, 33, 41]: [4, 48, 21, 33, 12, 25] , [Max, Min]: [48 , 4 , 23.833333333333332]
# order of [30, 40, 41, 47, 48, 49]: [41, 29, 25, 14, 1, 30] , [Max, Min]: [41 , 1 , 23.333333333333332]
# order of [1, 3, 18, 28, 42, 44]: [20, 2, 22, 37, 6, 28] , [Max, Min]: [37 , 2 , 19.166666666666668]
# order of [2, 5, 13, 18, 25, 36]: [38, 4, 8, 22, 3, 23] , [Max, Min]: [38 , 3 , 16.333333333333332]
# order of [1, 5, 10, 25, 32, 37]: [20, 4, 32, 3, 44, 15] , [Max, Min]: [44 , 3 , 19.666666666666668]
# BoundedIntText(value=57, description='number of entries: ', max=268)

# %% [markdown]
# ## Most common pairs

# %%
#print(COUNTERS_DF.index.get_loc(7))
COUNTERS_DF.iloc[COUNTERS_DF.index.get_loc(7)][7]
# Out:
# 40

# %%
#FILTERED_DF
FILTERED_DF.shape[1]
#for i in range(FILTERED_DF.shape[1])
# Out:
# 9

# %%
items_to_take=20
def do_filter_dt(start_from,number_of_items):
    filter_df = dt.iloc[start_from:start_from+number_of_items,:]
    #print("starting from date :", filter_df.iloc[filter_df.date.size-1][0] )
    #print("number of draws :", y ,"from " , filter_df.iloc[0][0] )
    counters = do_calculate_frequency(filter_df=filter_df)
    #t = counters
    counters['position'] = pd.Series(np.array(range(1,counters.index.size+1,1)), index=counters.index)
    
    #display(filter_df.transpose().style)
    #display(counters.transpose().style)
    global FILTERED_DF 
    FILTERED_DF = filter_df
    
    global COUNTERS_DF 
    COUNTERS_DF = counters
    
def do_order_of_frequency(a , counters_df):
    i=0
    order = []
    return_string = "order of " + str(a) +": "
    
    while i < len(a) : 
        try:
            order.append(counters_df.iloc[counters_df.index.get_loc(a[i])][7])
        except KeyError:
            order.append(-1)
        #return_string += str(COUNTERS_DF.iloc[COUNTERS_DF.index.get_loc(a[i])][7])+ " , " 
        i += 1
    #print(order)
    order_only_number = [x for x in order if x != -1]
    print(order_only_number)
    global FREQUENCY_ORDER_OF_NUMBERS
    
    try:
        if len(order_only_number) > 5:
            FREQUENCY_ORDER_OF_NUMBERS = return_string + str(order) + " , [Max, Min]: [" + str(max(order_only_number)) + " , " +str(min(order_only_number)) +" , " + str(np.mean(order_only_number))+ "] \nordered: " + str(np.sort(order_only_number)) + " count :" + str(len(order_only_number) ) 
        else :
            FREQUENCY_ORDER_OF_NUMBERS= "0"
        #FREQUENCY_ORDER_OF_NUMBERS =  "\nordered: " + str(np.sort(order_only_number)) + " count :" + str(len(order_only_number)) 
    except:
        print("error")
    #FREQUENCY_ORDER_OF_NUMBERS = return_string + str(order) + " , [Max, Min]: [" + str(max(order_only_number)) + " , " +str(min(order_only_number)) +" , " + str(np.mean(order_only_number))+ "] "

    return FREQUENCY_ORDER_OF_NUMBERS

i=1 
number_of_items = 6
while i < 200 :
    do_filter_dt(i,number_of_items)
    #list(dt.iloc[0,1:6])
    print("index: " + str(i-1) +" " + do_order_of_frequency(a=list(dt.iloc[i-1,1:7]), counters_df=COUNTERS_DF) +  " counters size: " +str(COUNTERS_DF.shape) )
    i +=1
# Out:
# [24]
# index: 0 0 counters size: (30, 8)
# [7, 16]
# index: 1 0 counters size: (29, 8)
# [14, 4]
# index: 2 0 counters size: (28, 8)
# [2, 27]
# index: 3 0 counters size: (27, 8)
# [3, 14]
# index: 4 0 counters size: (27, 8)
# [14, 10, 26]
# index: 5 0 counters size: (26, 8)
# [8, 24, 14]
# index: 6 0 counters size: (27, 8)
# [26, 24, 8, 14]
# index: 7 0 counters size: (27, 8)
# [24, 18, 7]
# index: 8 0 counters size: (25, 8)
# [23, 10, 14, 13]
# index: 9 0 counters size: (25, 8)
# [6, 21, 14, 5]
# index: 10 0 counters size: (26, 8)
# [3, 25]
# index: 11 0 counters size: (25, 8)
# [24, 11, 12]
# index: 12 0 counters size: (25, 8)
# [13, 24, 17, 12]
# index: 13 0 counters size: (25, 8)
# [19, 4, 2]
# index: 14 0 counters size: (25, 8)
# [23, 6, 10, 13]
# index: 15 0 counters size: (27, 8)
# [27, 23, 22]
# index: 16 0 counters size: (28, 8)
# [23, 19, 18]
# index: 17 0 counters size: (26, 8)
# [21, 2, 15, 8]
# index: 18 0 counters size: (29, 8)
# [27, 1, 9]
# index: 19 0 counters size: (29, 8)
# [21, 18]
# index: 20 0 counters size: (25, 8)
# [2, 21, 13, 27]
# index: 21 0 counters size: (27, 8)
# [21, 24, 23, 11]
# index: 22 0 counters size: (28, 8)
# [19, 21, 10, 11]
# index: 23 0 counters size: (27, 8)
# [27, 24, 22, 20, 11]
# index: 24 0 counters size: (28, 8)
# [12, 23, 11]
# index: 25 0 counters size: (25, 8)
# [10, 23, 14, 13]
# index: 26 0 counters size: (25, 8)
# [11, 4, 22, 18, 3, 25]
# index: 27 order of [2, 9, 11, 33, 47, 48]: [11, 4, 22, 18, 3, 25] , [Max, Min]: [25 , 3 , 13.833333333333334]
# ordered: [ 3  4 11 18 22 25] count :6 counters size: (25, 8)
# [3, 24, 21]
# index: 28 0 counters size: (26, 8)
# [6, 7, 21, 19]
# index: 29 0 counters size: (26, 8)
# [15]
# index: 30 0 counters size: (23, 8)
# [12, 25, 5, 15, 3]
# index: 31 0 counters size: (25, 8)
# [11, 25, 7, 8]
# index: 32 0 counters size: (26, 8)
# [19, 7, 28, 15, 9]
# index: 33 0 counters size: (28, 8)
# [26, 19, 15, 4]
# index: 34 0 counters size: (27, 8)
# [2, 27, 8, 4]
# index: 35 0 counters size: (29, 8)
# [9, 4]
# index: 36 0 counters size: (28, 8)
# [17, 14, 11]
# index: 37 0 counters size: (27, 8)
# [20, 9, 11, 16]
# index: 38 0 counters size: (30, 8)
# []
# index: 39 0 counters size: (27, 8)
# [4, 20]
# index: 40 0 counters size: (24, 8)
# [7, 19]
# index: 41 0 counters size: (23, 8)
# [15, 21, 9, 17, 13]
# index: 42 0 counters size: (23, 8)
# [8, 19, 15, 11]
# index: 43 0 counters size: (25, 8)
# [25, 4, 10]
# index: 44 0 counters size: (26, 8)
# [23, 2, 16, 3]
# index: 45 0 counters size: (30, 8)
# [25, 23, 19, 17, 10]
# index: 46 0 counters size: (30, 8)
# [6, 10, 3]
# index: 47 0 counters size: (28, 8)
# [26, 24, 21, 15]
# index: 48 0 counters size: (28, 8)
# [6, 9, 5]
# index: 49 0 counters size: (27, 8)
# [1, 23]
# index: 50 0 counters size: (23, 8)
# [12, 13, 19]
# index: 51 0 counters size: (22, 8)
# [1, 6, 10, 5, 20, 2]
# index: 52 order of [3, 5, 18, 31, 37, 45]: [1, 6, 10, 5, 20, 2] , [Max, Min]: [20 , 1 , 7.333333333333333]
# ordered: [ 1  2  5  6 10 20] count :6 counters size: (25, 8)
# [9, 17, 14, 4]
# index: 53 0 counters size: (24, 8)
# [14, 15, 8, 13, 5]
# index: 54 0 counters size: (25, 8)
# [25, 6, 1, 26]
# index: 55 0 counters size: (26, 8)
# [6]
# index: 56 0 counters size: (24, 8)
# [16, 22, 14, 6, 10]
# index: 57 0 counters size: (28, 8)
# [7, 15, 12]
# index: 58 0 counters size: (28, 8)
# [24, 23, 21, 14, 10]
# index: 59 0 counters size: (31, 8)
# [20, 17, 12, 31]
# index: 60 0 counters size: (31, 8)
# [23, 12, 13]
# index: 61 0 counters size: (29, 8)
# [22, 14]
# index: 62 0 counters size: (27, 8)
# [8, 16]
# index: 63 0 counters size: (25, 8)
# [17, 24, 7]
# index: 64 0 counters size: (25, 8)
# [5, 22, 9, 19]
# index: 65 0 counters size: (25, 8)
# [26, 23, 12, 2, 14]
# index: 66 0 counters size: (29, 8)
# [24, 23]
# index: 67 0 counters size: (28, 8)
# [25, 22, 8, 14]
# index: 68 0 counters size: (28, 8)
# [24, 20, 4, 11]
# index: 69 0 counters size: (29, 8)
# [14]
# index: 70 0 counters size: (28, 8)
# [19, 15]
# index: 71 0 counters size: (27, 8)
# [11]
# index: 72 0 counters size: (25, 8)
# [1, 3, 15]
# index: 73 0 counters size: (26, 8)
# [3, 22, 20, 13]
# index: 74 0 counters size: (26, 8)
# [21, 4, 22, 27]
# index: 75 0 counters size: (27, 8)
# [20, 23, 21, 17]
# index: 76 0 counters size: (27, 8)
# [17, 8, 20, 13]
# index: 77 0 counters size: (27, 8)
# [13]
# index: 78 0 counters size: (25, 8)
# [7, 5, 23, 16]
# index: 79 0 counters size: (26, 8)
# [19, 26, 24, 4, 23]
# index: 80 0 counters size: (28, 8)
# [23]
# index: 81 0 counters size: (25, 8)
# [10, 6, 7, 21]
# index: 82 0 counters size: (26, 8)
# [25, 22, 21, 16]
# index: 83 0 counters size: (28, 8)
# [25, 24, 23, 2, 4]
# index: 84 0 counters size: (28, 8)
# [4, 23, 20, 15, 9]
# index: 85 0 counters size: (30, 8)
# [22, 15, 14]
# index: 86 0 counters size: (29, 8)
# [25]
# index: 87 0 counters size: (26, 8)
# [11, 24, 19, 12]
# index: 88 0 counters size: (26, 8)
# [16, 18]
# index: 89 0 counters size: (24, 8)
# [22, 8, 20, 12]
# index: 90 0 counters size: (25, 8)
# [21, 11, 9]
# index: 91 0 counters size: (25, 8)
# [24, 23, 5, 15, 10]
# index: 92 0 counters size: (27, 8)
# [3, 15]
# index: 93 0 counters size: (26, 8)
# [17, 21, 3]
# index: 94 0 counters size: (27, 8)
# [19, 20, 18, 1]
# index: 95 0 counters size: (27, 8)
# [6, 27, 1]
# index: 96 0 counters size: (27, 8)
# [23, 2, 12]
# index: 97 0 counters size: (26, 8)
# [17, 12, 1]
# index: 98 0 counters size: (26, 8)
# [21, 8, 6, 10, 1]
# index: 99 0 counters size: (26, 8)
# [8, 4, 7]
# index: 100 0 counters size: (24, 8)
# [27, 24, 23, 20, 3, 29]
# index: 101 order of [14, 18, 19, 23, 37, 49]: [27, 24, 23, 20, 3, 29] , [Max, Min]: [29 , 3 , 21.0]
# ordered: [ 3 20 23 24 27 29] count :6 counters size: (29, 8)
# [21, 20, 6, 28]
# index: 102 0 counters size: (28, 8)
# [7, 13]
# index: 103 0 counters size: (28, 8)
# [24, 1, 7]
# index: 104 0 counters size: (28, 8)
# [8, 11, 3]
# index: 105 0 counters size: (27, 8)
# [4, 20, 13, 11]
# index: 106 0 counters size: (28, 8)
# [20, 2]
# index: 107 0 counters size: (26, 8)
# [13, 22]
# index: 108 0 counters size: (24, 8)
# [1, 18, 22, 21, 20, 15]
# index: 109 order of [2, 3, 17, 23, 27, 40]: [1, 18, 22, 21, 20, 15] , [Max, Min]: [22 , 1 , 16.166666666666668]
# ordered: [ 1 15 18 20 21 22] count :6 counters size: (26, 8)
# [25, 17, 14, 10]
# index: 110 0 counters size: (27, 8)
# [10, 21]
# index: 111 0 counters size: (24, 8)
# [25, 24, 3, 13, 11, 10]
# index: 112 order of [13, 17, 29, 38, 41, 42]: [25, 24, 3, 13, 11, 10] , [Max, Min]: [25 , 3 , 14.333333333333334]
# ordered: [ 3 10 11 13 24 25] count :6 counters size: (27, 8)
# [10]
# index: 113 0 counters size: (25, 8)
# [18, 1, 6]
# index: 114 0 counters size: (25, 8)
# [8, 23, 12, 25]
# index: 115 0 counters size: (25, 8)
# [8, 18, 10, 15, 13]
# index: 116 0 counters size: (26, 8)
# [7, 19, 8]
# index: 117 0 counters size: (26, 8)
# [22, 12, 4]
# index: 118 0 counters size: (25, 8)
# [9, 16, 19]
# index: 119 0 counters size: (25, 8)
# [25, 26, 23, 18, 10]
# index: 120 0 counters size: (28, 8)
# [20, 19, 18]
# index: 121 0 counters size: (28, 8)
# [22, 1, 8]
# index: 122 0 counters size: (30, 8)
# [7, 14]
# index: 123 0 counters size: (28, 8)
# [7, 14]
# index: 124 0 counters size: (26, 8)
# [20, 3, 11]
# index: 125 0 counters size: (25, 8)
# [2, 21, 13, 10]
# index: 126 0 counters size: (27, 8)
# [9, 18, 17]
# index: 127 0 counters size: (25, 8)
# [25, 3, 4]
# index: 128 0 counters size: (26, 8)
# [20, 17, 16]
# index: 129 0 counters size: (28, 8)
# [18, 12]
# index: 130 0 counters size: (27, 8)
# [16, 22, 21, 19]
# index: 131 0 counters size: (28, 8)
# [16, 15, 12, 11]
# index: 132 0 counters size: (27, 8)
# [13, 14, 19]
# index: 133 0 counters size: (24, 8)
# [11, 15, 17]
# index: 134 0 counters size: (24, 8)
# [23, 17, 13, 11]
# index: 135 0 counters size: (26, 8)
# [16, 23, 3, 25]
# index: 136 0 counters size: (25, 8)
# [5, 19, 18]
# index: 137 0 counters size: (24, 8)
# [23, 19, 9, 14]
# index: 138 0 counters size: (24, 8)
# [17, 19, 2, 25]
# index: 139 0 counters size: (25, 8)
# [3, 24, 6, 14]
# index: 140 0 counters size: (25, 8)
# [8, 9, 22, 19, 15]
# index: 141 0 counters size: (26, 8)
# [9, 10, 22, 7]
# index: 142 0 counters size: (26, 8)
# [12, 8, 27, 21, 28]
# index: 143 0 counters size: (28, 8)
# [21, 2, 18]
# index: 144 0 counters size: (30, 8)
# [1, 6, 13, 11]
# index: 145 0 counters size: (28, 8)
# [22, 2, 18]
# index: 146 0 counters size: (26, 8)
# [16, 27, 7, 14]
# index: 147 0 counters size: (28, 8)
# [27, 1, 10, 3]
# index: 148 0 counters size: (28, 8)
# [17, 3]
# index: 149 0 counters size: (28, 8)
# [22, 16]
# index: 150 0 counters size: (26, 8)
# [25, 16, 10]
# index: 151 0 counters size: (26, 8)
# [8, 10, 11]
# index: 152 0 counters size: (25, 8)
# [20, 9, 14, 5, 27]
# index: 153 0 counters size: (27, 8)
# [28, 23, 18, 10]
# index: 154 0 counters size: (29, 8)
# [25, 12]
# index: 155 0 counters size: (29, 8)
# [6, 23]
# index: 156 0 counters size: (27, 8)
# [26, 24, 22, 6]
# index: 157 0 counters size: (27, 8)
# [23, 16, 13]
# index: 158 0 counters size: (26, 8)
# [16, 5, 4, 6]
# index: 159 0 counters size: (26, 8)
# [16, 3, 14]
# index: 160 0 counters size: (24, 8)
# [8, 4]
# index: 161 0 counters size: (25, 8)
# [21, 13, 12]
# index: 162 0 counters size: (25, 8)
# [8, 14, 5, 10]
# index: 163 0 counters size: (26, 8)
# [6, 18, 24, 20, 19]
# index: 164 0 counters size: (29, 8)
# [26, 22]
# index: 165 0 counters size: (28, 8)
# [20, 11, 10, 5]
# index: 166 0 counters size: (30, 8)
# [3]
# index: 167 0 counters size: (28, 8)
# [15, 12, 4, 8, 7]
# index: 168 0 counters size: (31, 8)
# [18]
# index: 169 0 counters size: (29, 8)
# [21, 10, 27]
# index: 170 0 counters size: (27, 8)
# [5, 1]
# index: 171 0 counters size: (24, 8)
# [14, 8, 5]
# index: 172 0 counters size: (22, 8)
# [17, 14, 13, 22]
# index: 173 0 counters size: (22, 8)
# [1, 11]
# index: 174 0 counters size: (22, 8)
# [9, 20, 3, 8, 7]
# index: 175 0 counters size: (26, 8)
# [24, 6, 3, 10, 8, 14]
# index: 176 order of [13, 19, 20, 38, 39, 44]: [24, 6, 3, 10, 8, 14] , [Max, Min]: [24 , 3 , 10.833333333333334]
# ordered: [ 3  6  8 10 14 24] count :6 counters size: (30, 8)
# [21, 15, 19, 24, 23]
# index: 177 0 counters size: (30, 8)
# [8]
# index: 178 0 counters size: (27, 8)
# [7, 14, 11, 4]
# index: 179 0 counters size: (28, 8)
# [23, 4, 30]
# index: 180 0 counters size: (30, 8)
# [22, 25, 20]
# index: 181 0 counters size: (28, 8)
# [11]
# index: 182 0 counters size: (28, 8)
# [21, 18, 7, 29]
# index: 183 0 counters size: (29, 8)
# [15, 14]
# index: 184 0 counters size: (29, 8)
# [27, 8, 14, 1]
# index: 185 0 counters size: (30, 8)
# [8, 14, 13]
# index: 186 0 counters size: (29, 8)
# [20, 14, 13]
# index: 187 0 counters size: (28, 8)
# [10, 14]
# index: 188 0 counters size: (26, 8)
# [21, 9, 15]
# index: 189 0 counters size: (25, 8)
# [1, 7, 11]
# index: 190 0 counters size: (25, 8)
# [25, 3, 21]
# index: 191 0 counters size: (26, 8)
# [8, 25, 3, 4, 16]
# index: 192 0 counters size: (27, 8)
# [1, 14, 12]
# index: 193 0 counters size: (27, 8)
# [3, 19, 16]
# index: 194 0 counters size: (27, 8)
# [17, 20, 28, 27, 8]
# index: 195 0 counters size: (29, 8)
# [26, 23]
# index: 196 0 counters size: (29, 8)
# [24, 5, 1]
# index: 197 0 counters size: (27, 8)
# [21, 4, 14]
# index: 198 0 counters size: (27, 8)

# %%
#COUNTERS_DF
t = COUNTERS_DF 
##t.asign+ position pd.Series(np.array(range(1,49,1)), index=COUNTERS_DF.index)
t['position'] = pd.Series(np.array(range(1,COUNTERS_DF.index.size+1,1)), index=COUNTERS_DF.index)
#t.assign('postion' = pd.Series(np.array(range(1,COUNTERS_DF.index.size+1,1)), index=COUNTERS_DF.index))
print(COUNTERS_DF.index.size)
k=[1,25,41,40,37,49,5,6,42,48,13,17,18,29,38,39,3,8,43,36,45,46,47,44,32,35,33,9,30,2,7,24,22,20,19,16,14,10,28]
np.sort(k)

# %%
COUNTERS_DF.shape

# %% [raw]
# display(dt.iloc[1:58,0:7].style)

# %%
print("c20:" + str(20*19*18*17*16*15 /(6*5*4*3*2*1)))
print("c18:" + str(18*17*16*15*14*13 /(6*5*4*3*2*1)))
print("c15:" + str(15*14*13*12*11*10 /(6*5*4*3*2*1)))

# %% [markdown]
# <a id='s10'></a>

# %% [markdown]
# <a href='#the_destination'>Link to the destination'</a>

# %%
a=[31,3,5,9,34,48,47,44,43,42,37,1,33,2,25,19,17,12,11,49]
np.sort(a)

# %%
dt.iloc[0:3,0:7].style

# %%
dt.iloc[0:3,:].style

# %%
#kt = dt.iloc[0:200,:]
kt=dt
kt['even'] = pd.Series(np.zeros((kt.index.size,), dtype=int), index=kt.index)
kt['odd']  = pd.Series(np.zeros((kt.index.size,), dtype=int), index=kt.index)
kt['high'] = pd.Series(np.zeros((kt.index.size,), dtype=int), index=kt.index)
kt['low']  = pd.Series(np.zeros((kt.index.size,), dtype=int), index=kt.index)

#kt

# %%
low_number_till=30
for index, row in kt.iterrows() :
    #for i in row
    #print(str(index) + str(row))
    even = [i for i in row[1:7] if i%2==0]
    odd  = [i for i in row[1:7] if i%2!=0]
    high = [i for i in row[1:7] if i>low_number_till]
    low  = [i for i in row[1:7] if i<low_number_till]
    print(row[1:7])
    print(high)
    print(len(high))
    #print(low)
    #display(row)
    kt.at[index,'even'] = np.count_nonzero(even)
    kt.at[index,'odd']  = np.count_nonzero(odd)
    kt.at[index,'high'] = len(high)
    kt.at[index,'low']  = len(low)
    #print(even)
#kt
    #print(len(even))

# %%
#np.zeros((kt.index.size,), dtype=int)

# %%
#pd.Series(np.zeros((kt.index.size,), dtype=int), index=kt.index)

# %%
#range(1,kt.index.size+1,1)

# %%
kt.index.size

# %%
#print(kt.to_string())
kt
