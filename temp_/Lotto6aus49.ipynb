# %%
import pandas as pd 
import numpy as np
from collections import Counter
pd.options.display.max_colwidth =100

# %% [markdown]
# ## Reading files

# %%
df2018=pd.read_csv("C:\\Users\\CapesAndHates\\Desktop\\lottodata\\2018.txt")
df2017=pd.read_csv("C://Users//CapesAndHates//Desktop//lottodata\\2017.txt")

#fromating data
dt2018 =df2018.rename(columns={'Date': 'date', 'number1' : 'n1', 'number2':'n2', 'number3':'n3', 'number4':'n4', 'number5':'n5',
       'number6':'n6', 'number7':'n7', 'jackpot clamied': 'jackpot'}, index ={})
dt2018.date= pd.to_datetime(dt2018.date)
dt2017 =df2017.rename(columns={'Date': 'date', 'number1' : 'n1', 'number2':'n2', 'number3':'n3', 'number4':'n4', 'number5':'n5',
       'number6':'n6', 'number7':'n7', 'jackpot clamied': 'jackpot'}, index ={})
dt2017.date= pd.to_datetime(dt2017.date)

# %%
#dt2018.n1

# %% [markdown]
# ## Calculating frequency of each number

# %%
n1c=Counter(dt2018.n1)
n2c=Counter(dt2018.n2)
n3c=Counter(dt2018.n3)
n4c=Counter(dt2018.n4)
n5c=Counter(dt2018.n5)
n6c=Counter(dt2018.n6)


tempdict= Counter(dict.fromkeys(range(1,49),0))
#print(tempdict)
print(n1c)
k = n1c+tempdict
k1= n1c+n2c+n3c+n4c+n5c+n6c
#print(k)
#print("k1 :", k1)

#print([*k.keys()])
# Out:
# Counter({3: 11, 1: 8, 5: 6, 2: 4, 13: 4, 4: 4, 6: 3, 15: 3, 8: 2, 10: 2, 12: 2, 30: 1, 16: 1, 7: 1, 23: 1, 9: 1, 20: 1, 18: 1, 17: 1})

# %%
def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

# %%
sum1 = n1c+n2c+n3c+n4c+n5c+n6c
data = [n1c,n2c,n3c,n4c,n5c,n6c,sum1]
index =["first", "second", "third", "forth", "fifth", "six", "sum"]
temp =pd.DataFrame(data, index=index)
temp=temp.replace(np.nan,0)
temp=temp.astype('int')
datacounter=temp.transpose()
datacounter['first'].values
datacounter=datacounter.sort_values(by='sum', ascending=False)
#temp.style
datacounter.style
#datacounter.as_matrix(columns=datacounter.[])
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_72da409c_932d_11e8_b8b8_0050b66ae298" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >first</th>
#         <th class="col_heading level0 col1" >second</th>
#         <th class="col_heading level0 col2" >third</th>
#         <th class="col_heading level0 col3" >forth</th>
#         <th class="col_heading level0 col4" >fifth</th>
#         <th class="col_heading level0 col5" >six</th>
#         <th class="col_heading level0 col6" >sum</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_72da409c_932d_11e8_b8b8_0050b66ae298level0_row0" class="row_heading level0 row0" >48</th>
#         <td id="T_72da409c_932d_11e8_b8b8_0050b66ae298row0_col0" class="data row0 col0" >0</td>
#         <td id="T_72da409c_932d_11e8_b8b8_0050b66ae298row0_col1" class="data row0 col1" >0</td>
#         <td id="T_72da409c_932d_11e8_b8b8_0050b66ae298row0_col2" class="data row0 col2" >0</td>
# ...

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [9, 2.5]
plt.rcParams['figure.dpi']=200
plt.figure(figsize=(18, 16), dpi= 1000, facecolor='w', edgecolor='k')
#datacounter.plot.hist(alpha=1)
datacounter.plot.bar()
#plt.show()

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import cufflinks as cf
#data = [go.Histogram(yx=df['y'])]
cf.set_config_file(offline=False, world_readable=True, theme='pearl')

datacounter.iplot(kind='histogram', filename='cufflinks/multiple-histograms')
# Out:
# C:\Users\CapesAndHates\Anaconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:558: DeprecationWarning:
#
# plotly.graph_objs.YAxis is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.YAxis
#   - plotly.graph_objs.layout.scene.YAxis
#
#
# C:\Users\CapesAndHates\Anaconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:531: DeprecationWarning:
#
# plotly.graph_objs.XAxis is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.XAxis
#   - plotly.graph_objs.layout.scene.XAxis
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-e9e7557e9a89> in <module>()
#       5 cf.set_config_file(offline=False, world_readable=True, theme='pearl')
#       6
# ----> 7 datacounter.iplot(kind='histogram', filename='cufflinks/multiple-histograms')
#
# ...

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.plotly as py
import plotly.graph_objs as go
init_notebook_mode(connected=True)
empty = x= dict.fromkeys(range(1,49),0)


x1=datacounter['first'].values

x2=datacounter['second'].values



trace1 = go.Histogram(
    x=x1,y=y1,
    name='number1',
    xbins=dict(
        start=1,
        end=49,
        size=1
    ),
   
    opacity=0.75
)
trace2 = go.Histogram(
    x=x2,
    name='number2',
    xbins=dict(
        start=1,
        end=49,
        size=1
    ),
    
    opacity=0.75
)
data = [trace1, trace2]

layout = go.Layout(
    title='Sampled Results',
    xaxis=dict(
        title='Value'
    ),
    yaxis=dict(
        title='Count'
    )
    #bargap=0.2,
    #bargroupgap=0.1
    #barmoode='stack'
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='styled histogram')

# %%
print(n1c)
print(list(n1c.keys()))
print(n1c.values())
print(*n1c.keys())
#k = dt2018['n1'].value_counts() + dt
x = np.random.randn(50)
print(x)

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.plotly as py
import plotly.graph_objs as go
init_notebook_mode(connected=True)
empty = x= dict.fromkeys(range(1,49),0)

y1=[*n1c.values()]
x1=[*n1c.keys()]
y2=[*n2c.values()]
x2=[*n2c.keys()]



trace1 = go.Histogram(
    x=x1,y=y1,
    name='number1',
    xbins=dict(
        start=1,
        end=49,
        size=1
    ),
   
    opacity=0.75
)
trace2 = go.Histogram(
    x=x2,y=y2,
    name='number2',
    xbins=dict(
        start=1,
        end=49,
        size=1
    ),
    
    opacity=0.75
)
data = [trace1, trace2]

layout = go.Layout(
    title='Sampled Results',
    xaxis=dict(
        title='Value'
    ),
    yaxis=dict(
        title='Count'
    )
    #bargap=0.2,
    #bargroupgap=0.1
    #barmoode='stack'
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='styled histogram')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~guruvishna04/8.embed" height="525px" width="100%"></iframe>

# %%
dict(start = 1,end = 49,size = 1)
# Out:
# {'start': 1, 'end': 49, 'size': 1}
